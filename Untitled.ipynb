# %%
# !pip install ydata-profiling

# %%
import pandas as pd

# %%
from ydata_profiling import ProfileReport

# %%
census_raw = pd.read_csv("data/census.csv")

# %%
census_profile = ProfileReport(census_raw, title="Census Profile")

# %%
census_profile.to_file("census_profile.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
